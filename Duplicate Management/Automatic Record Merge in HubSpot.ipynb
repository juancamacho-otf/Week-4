# %% [markdown]
# # Automatic Record Merge in HubSpot

# %% [markdown]
# Nosotros realizamos un merge automatico de registros en HubSpot mediante la implementación de la herramienta de "Merge records" de HubSpot, por lo cual el merge se rige bajo las siguientes normas:

# %% [markdown]
# **Doc:** https://knowledge.hubspot.com/crm-setup/merge-records

# %% [markdown]
# Esta implementación de la herramienta de HubSpot la realizamo a traves de la API.

# %% [markdown]
# Este codigo trabaja haciendo uso del "Key" de los duplicados que obtenemos despues de implementar las funciones de encontrar duplicados.

# %% [markdown]
# # Set environment variables

# %%
import os

# %%
os.environ["path"] = r"C:\Users\Juan Pablo Pelaez\Documents\PyDev-Operational-Library-For-Data-Engineers"
os.environ["access_token"] = 'pat-na1-3fa39b1a-5a4d-4161-a611-8d99019072b9'
os.environ["records_object_type"] = 'contacts'
os.environ["file_path"] = r"C:\Users\Juan Pablo Pelaez\Documents\Training\Training APIs"
os.environ["file_name"] = 'Duplicate Contact Records Found.xlsx'

# %% [markdown]
# ## Libraries

# %%
import requests
import json

import pandas as pd
import numpy as np

from IPython.display import Markdown, display
def printmd(string):
    display(Markdown(string))

from IPython.display import display, HTML, clear_output

# %% [markdown]
# #### Data team library

# %% [markdown]
# Your library path

# %%
path = os.getenv('path')

# %%
import sys
sys.path.insert(0,path)

from functions.data_transformations.delete_unnecessary_blank_spaces import delete_unnecessary_blank_spaces

# %% [markdown]
# ## Parameters - Input Values

# %% [markdown]
# #### Access API

# %%
access_token = os.getenv('access_token') # Input

headers = {'Content-Type': 'application/json',
            'authorization': 'Bearer {}'.format(access_token)}

# %% [markdown]
# #### Info Records

# %%
records_object_type = os.getenv('records_object_type')

# %% [markdown]
# #### Frame

# %%
file_path = os.getenv('file_path')

# %%
file_path
# Out:
# 'C:\\Users\\Juan Pablo Pelaez\\Documents\\Training\\Training APIs'

# %%
file_name = os.getenv('file_name')

# %%
file_name
# Out:
# 'Duplicate Contact Records Found.xlsx'

# %%
df = pd.read_excel(file_path+'\\'+file_name)

# %%
df = df.replace(np.nan, '')

# %%
df
# Out:
#         Record ID First Name Last Name      Phone Number  \
# 0    102020159252      Tyson    Newman  (+353) 8350 2738
# 1    102021803047                       (+353) 8350 2738
# 2    102033748778
# 3    102023206209                       (+353) 8350 2738
# 4    102033410128                        (+44) 5172 2704
# ..            ...        ...       ...               ...
# 274  102021803049       Alan    Warner   (+44) 2602 8217
# 275  102021344113       Alan    Warner   (+44) 2602 8217
# 276  102021803051
# 277  102020822178                        (+44) 2602 8217
# 278  102033443462
#
#                                       Email  \
# 0          tyson_newman1021718471@yahoo.com
# 1          tyson_newman1021718471@yahoo.com
# 2          tyson_newman1021718471@yahoo.com
# 3          tyson_newman1021718471@yahoo.com
# 4    sebastian_parker1458479109@joiniaa.com
# ..                                      ...
# 274          alan_warner22954315@fuliss.net
# 275          alan_warner22954315@fuliss.net
# 276          alan_warner22954315@fuliss.net
# 277          alan_warner22954315@fuliss.net
# 278          alan_warner22954315@fuliss.net
#
#                                   original mail       Create Date  \
# 0          tyson_newman1021718471+103@yahoo.com  2025-02-25 07:58
# 1          tyson_newman1021718471+101@yahoo.com  2025-02-25 07:58
# 2              tyson_newman1021718471@yahoo.com  2025-02-25 07:58
# 3          tyson_newman1021718471+102@yahoo.com  2025-02-25 07:58
# 4    sebastian_parker1458479109+101@joiniaa.com  2025-02-25 07:58
# ..                                          ...               ...
# 274          alan_warner22954315+101@fuliss.net  2025-02-25 07:58
# 275              alan_warner22954315@fuliss.net  2025-02-25 07:58
# 276          alan_warner22954315+104@fuliss.net  2025-02-25 07:58
# 277          alan_warner22954315+103@fuliss.net  2025-02-25 07:58
# 278          alan_warner22954315+102@fuliss.net  2025-02-25 07:58
#
#     Last Activity Date
# 0
# 1
# 2
# 3
# 4
# ..                 ...
# 274
# 275
# 276
# 277
# 278
#
# [279 rows x 8 columns]

# %%
printmd("<h3><span style='color:blue'>You will work with {} records</span></h3>".format(len(df)))
# Out:
# <h3><span style='color:blue'>You will work with 279 records</span></h3>

# %%
df.head(5)
# Out:
#       Record ID First Name Last Name      Phone Number  \
# 0  102020159252      Tyson    Newman  (+353) 8350 2738
# 1  102021803047                       (+353) 8350 2738
# 2  102033748778
# 3  102023206209                       (+353) 8350 2738
# 4  102033410128                        (+44) 5172 2704
#
#                                     Email  \
# 0        tyson_newman1021718471@yahoo.com
# 1        tyson_newman1021718471@yahoo.com
# 2        tyson_newman1021718471@yahoo.com
# 3        tyson_newman1021718471@yahoo.com
# 4  sebastian_parker1458479109@joiniaa.com
#
#                                 original mail       Create Date  \
# 0        tyson_newman1021718471+103@yahoo.com  2025-02-25 07:58
# 1        tyson_newman1021718471+101@yahoo.com  2025-02-25 07:58
# 2            tyson_newman1021718471@yahoo.com  2025-02-25 07:58
# 3        tyson_newman1021718471+102@yahoo.com  2025-02-25 07:58
# 4  sebastian_parker1458479109+101@joiniaa.com  2025-02-25 07:58
#
#   Last Activity Date
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Empty Keys

# %% [markdown]
# Vamos a realizar una pequeña revisión de las Keys, no debe existir ninguna key que este en blanco, realizar un merge de registros con keys vacias podria incluso eliminar bases de datos completas.

# %%
df['Key'] = df['Email'].apply(delete_unnecessary_blank_spaces)

# %%
detect_empty_keys = df.loc[df['Key'] == '']

if len(detect_empty_keys) != 0:
    printmd("<h3><span style='color:red'>There are keys configured as empty</span></h3> please check these keys that are empty [''], otherwise you will end up making merges that should not be made.")
else:
     printmd("<h3><span style='color:green'>Keys are properly configured</span></h3> Go ahead!")
# Out:
# <h3><span style='color:green'>Keys are properly configured</span></h3> Go ahead!

# %%
detect_empty_keys
# Out:
# Empty DataFrame
# Columns: [Record ID, First Name, Last Name, Phone Number, Email, original mail, Create Date, Last Activity Date, Key]
# Index: []

# %% [markdown]
# ## Define number of duplicates

# %% [markdown]
# En esta longitud de valores seremos capaces de recorrer todo el frame de duplicados, obteniendo todas las key unicas que nos señalan los duplicados.

# %%
duplicates = df.drop_duplicates(subset=['Key'])
duplicates = duplicates.reset_index(drop=True)

# %%
duplicates
# Out:
#        Record ID First Name Last Name      Phone Number  \
# 0   102020159252      Tyson    Newman  (+353) 8350 2738
# 1   102033410128                        (+44) 5172 2704
# 2   102032514367
# 3   102033492005       Ryan    Welsch   (+44) 7786 3560
# 4   102020032396
# 5   102033185298      Roger     Jones
# 6   102033030275      Rocco    Palmer   (+44) 8134 0522
# 7   102031826464
# 8   102020822173
# 9   102033395078    Phillip    Cooper   (+44) 2026 4200
# 10  102020173872       Owen    Wigley  (+353) 8027 1340
# 11  102032981851
# 12  102031826463                        (+44) 1566 8608
# 13  102021356296
# 14  102033748782
# 15  102021310094
# 16  102032900715      Mason   Redfern
# 17  102031826470
# 18  102021089875
# 19  102031826472       Kurt       May
# 20  102022212752                        (+44) 6285 0874
# 21  101981384982     Julian    Farrow  (+353) 6726 5335
# 22  102033476954     Julian      Bell
# 23  102021939023                       (+353) 1260 0667
# 24  102020858685       Jack     Nobbs   (+44) 1043 5603
# 25  102032465516                        (+44) 2524 7223
# 26  102033185293
# 27  102008768948
# 28  102021918099                        (+44) 7425 2015
# 29  102020875012       Hank   Roberts   (+44) 6552 2121
# 30  102033410140
# 31  101981384979      Ethan  Reynolds   (+44) 4452 6542
# 32  102021344114
# 33  102033299732    Eduardo     Quinn   (+44) 6608 1771
# 34  101986147885                       (+353) 8508 4383
# 35  102021599155    Eduardo     Glynn   (+44) 4534 8838
# 36  102021939025
# 37  102021356299
# 38  102033508269
# 39  102021599145                        (+44) 2042 3631
# 40  102033266575    Chester   Windsor  (+353) 3180 8645
# 41  102033443460       Chad  Paterson
# 42  102033459778      Bryon     James  (+353) 2407 1135
# 43  102022229532                        (+44) 1232 4125
# 44  102032465515       Brad      Nash   (+44) 7371 8278
# 45  102033251218       Brad     Casey   (+44) 7364 5886
# 46  102021918101
# 47  102033508280
# 48  102022229541
# 49  102021803049       Alan    Warner   (+44) 2602 8217
#
#                                      Email  \
# 0         tyson_newman1021718471@yahoo.com
# 1   sebastian_parker1458479109@joiniaa.com
# 2      sebastian_hope1518365261@hourpy.biz
# 3          ryan_welsch107397896@famism.biz
# 4          ryan_upsdell175534425@vetan.org
# 5         roger_jones1323472465@gompie.com
# 6    rocco_palmer160419466@infotech44.tech
# 7         rocco_martin507925367@eirey.tech
# 8        ramon_preston2096761104@sheye.org
# 9       phillip_cooper2140654386@jiman.org
# 10          owen_wigley177952980@extex.org
# 11   oliver_blackburn1495449589@kideod.biz
# 12           noah_tanner17953585@acrit.org
# 13            nate_roth902590743@liret.org
# 14       michael_veale472491137@gembat.biz
# 15      matthew_fowler696833773@kideod.biz
# 16       mason_redfern1913258047@extex.org
# 17        leroy_harris84853752@bulaffy.com
# 18          leroy_dwyer505528803@brety.org
# 19            kurt_may1371640774@corti.com
# 20       julius_corbett117840293@jiman.org
# 21      julian_farrow1141858439@gembat.biz
# 22        julian_bell2037709199@bauros.biz
# 23  johnathan_campbell236114447@typill.biz
# 24          jack_nobbs214667606@supunk.biz
# 25        henry_parker936902021@fuliss.net
# 26      harvey_pearson1222727439@twace.org
# 27     harvey_jackson1123990488@naiker.biz
# 28        harry_tutton509901574@typill.biz
# 29       hank_roberts1808907109@twipet.com
# 30    george_radcliffe235655210@nanoff.biz
# 31     ethan_reynolds1948188016@fuliss.net
# 32         erick_holt2014841980@ovock.tech
# 33      eduardo_quinn1602340966@famism.biz
# 34      eduardo_long1683975626@bretoux.com
# 35       eduardo_glynn1811301568@tonsy.org
# 36        denis_boyle1570473023@gompie.com
# 37       denis_amstead1787356310@acrit.org
# 38        daniel_owen1303681224@fuliss.net
# 39          clint_yard287681084@iatim.tech
# 40     chester_windsor1604043110@extex.org
# 41      chad_paterson2093044322@typill.biz
# 42         bryon_james964377164@gompie.com
# 43        brad_turner714061428@bretoux.com
# 44           brad_nash201967772@ovock.tech
# 45            brad_casey91675552@extex.org
# 46            bart_lyon420184376@acrit.org
# 47          barry_ryan1600445419@twace.org
# 48   anthony_sinclair1094808725@bungar.biz
# 49          alan_warner22954315@fuliss.net
#
#                                  original mail       Create Date  \
# 0         tyson_newman1021718471+103@yahoo.com  2025-02-25 07:58
# 1   sebastian_parker1458479109+101@joiniaa.com  2025-02-25 07:58
# 2      sebastian_hope1518365261+102@hourpy.biz  2025-02-25 07:58
# 3          ryan_welsch107397896+103@famism.biz  2025-02-25 07:58
# 4          ryan_upsdell175534425+105@vetan.org  2025-02-25 07:58
# 5             roger_jones1323472465@gompie.com  2025-02-25 07:58
# 6    rocco_palmer160419466+106@infotech44.tech  2025-02-25 07:58
# 7         rocco_martin507925367+103@eirey.tech  2025-02-25 07:58
# 8        ramon_preston2096761104+104@sheye.org  2025-02-25 07:58
# 9       phillip_cooper2140654386+104@jiman.org  2025-02-25 07:58
# 10          owen_wigley177952980+101@extex.org  2025-02-25 07:58
# 11   oliver_blackburn1495449589+101@kideod.biz  2025-02-25 07:58
# 12           noah_tanner17953585+106@acrit.org  2025-02-25 07:58
# 13            nate_roth902590743+103@liret.org  2025-02-25 07:58
# 14       michael_veale472491137+101@gembat.biz  2025-02-25 07:58
# 15      matthew_fowler696833773+101@kideod.biz  2025-02-25 07:58
# 16       mason_redfern1913258047+102@extex.org  2025-02-25 07:58
# 17        leroy_harris84853752+102@bulaffy.com  2025-02-25 07:58
# 18          leroy_dwyer505528803+104@brety.org  2025-02-25 07:58
# 19            kurt_may1371640774+103@corti.com  2025-02-25 07:58
# 20       julius_corbett117840293+105@jiman.org  2025-02-25 07:58
# 21          julian_farrow1141858439@gembat.biz  2025-02-25 07:58
# 22            julian_bell2037709199@bauros.biz  2025-02-25 07:58
# 23  johnathan_campbell236114447+102@typill.biz  2025-02-25 07:58
# 24          jack_nobbs214667606+104@supunk.biz  2025-02-25 07:58
# 25        henry_parker936902021+103@fuliss.net  2025-02-25 07:58
# 26          harvey_pearson1222727439@twace.org  2025-02-25 07:58
# 27     harvey_jackson1123990488+102@naiker.biz  2025-02-25 07:58
# 28        harry_tutton509901574+101@typill.biz  2025-02-25 07:58
# 29       hank_roberts1808907109+103@twipet.com  2025-02-25 07:58
# 30    george_radcliffe235655210+101@nanoff.biz  2025-02-25 07:58
# 31     ethan_reynolds1948188016+102@fuliss.net  2025-02-25 07:58
# 32         erick_holt2014841980+101@ovock.tech  2025-02-25 07:58
# 33          eduardo_quinn1602340966@famism.biz  2025-02-25 07:58
# 34      eduardo_long1683975626+103@bretoux.com  2025-02-25 07:58
# 35       eduardo_glynn1811301568+102@tonsy.org  2025-02-25 07:58
# 36        denis_boyle1570473023+104@gompie.com  2025-02-25 07:58
# 37       denis_amstead1787356310+101@acrit.org  2025-02-25 07:58
# 38            daniel_owen1303681224@fuliss.net  2025-02-25 07:58
# 39          clint_yard287681084+106@iatim.tech  2025-02-25 07:58
# 40     chester_windsor1604043110+104@extex.org  2025-02-25 07:58
# 41      chad_paterson2093044322+102@typill.biz  2025-02-25 07:58
# 42         bryon_james964377164+105@gompie.com  2025-02-25 07:58
# 43        brad_turner714061428+103@bretoux.com  2025-02-25 07:58
# 44           brad_nash201967772+104@ovock.tech  2025-02-25 07:58
# 45                brad_casey91675552@extex.org  2025-02-25 07:58
# 46            bart_lyon420184376+102@acrit.org  2025-02-25 07:58
# 47          barry_ryan1600445419+101@twace.org  2025-02-25 07:58
# 48   anthony_sinclair1094808725+101@bungar.biz  2025-02-25 07:58
# 49          alan_warner22954315+101@fuliss.net  2025-02-25 07:58
#
#    Last Activity Date                                     Key
# 0                            tyson_newman1021718471@yahoo.com
# 1                      sebastian_parker1458479109@joiniaa.com
# 2                         sebastian_hope1518365261@hourpy.biz
# 3                             ryan_welsch107397896@famism.biz
# 4                             ryan_upsdell175534425@vetan.org
# 5                            roger_jones1323472465@gompie.com
# 6                       rocco_palmer160419466@infotech44.tech
# 7                            rocco_martin507925367@eirey.tech
# 8                           ramon_preston2096761104@sheye.org
# 9                          phillip_cooper2140654386@jiman.org
# 10                             owen_wigley177952980@extex.org
# 11                      oliver_blackburn1495449589@kideod.biz
# 12                              noah_tanner17953585@acrit.org
# 13                               nate_roth902590743@liret.org
# 14                          michael_veale472491137@gembat.biz
# 15                         matthew_fowler696833773@kideod.biz
# 16                          mason_redfern1913258047@extex.org
# 17                           leroy_harris84853752@bulaffy.com
# 18                             leroy_dwyer505528803@brety.org
# 19                               kurt_may1371640774@corti.com
# 20                          julius_corbett117840293@jiman.org
# 21                         julian_farrow1141858439@gembat.biz
# 22                           julian_bell2037709199@bauros.biz
# 23                     johnathan_campbell236114447@typill.biz
# 24                             jack_nobbs214667606@supunk.biz
# 25                           henry_parker936902021@fuliss.net
# 26                         harvey_pearson1222727439@twace.org
# 27                        harvey_jackson1123990488@naiker.biz
# 28                           harry_tutton509901574@typill.biz
# 29                          hank_roberts1808907109@twipet.com
# 30                       george_radcliffe235655210@nanoff.biz
# 31                        ethan_reynolds1948188016@fuliss.net
# 32                            erick_holt2014841980@ovock.tech
# 33                         eduardo_quinn1602340966@famism.biz
# 34                         eduardo_long1683975626@bretoux.com
# 35                          eduardo_glynn1811301568@tonsy.org
# 36                           denis_boyle1570473023@gompie.com
# 37                          denis_amstead1787356310@acrit.org
# 38                           daniel_owen1303681224@fuliss.net
# 39                             clint_yard287681084@iatim.tech
# 40                        chester_windsor1604043110@extex.org
# 41                         chad_paterson2093044322@typill.biz
# 42                            bryon_james964377164@gompie.com
# 43                           brad_turner714061428@bretoux.com
# 44                              brad_nash201967772@ovock.tech
# 45                               brad_casey91675552@extex.org
# 46                               bart_lyon420184376@acrit.org
# 47                             barry_ryan1600445419@twace.org
# 48                      anthony_sinclair1094808725@bungar.biz
# 49                             alan_warner22954315@fuliss.net

# %%
df.head(4)
# Out:
#       Record ID First Name Last Name      Phone Number  \
# 0  102020159252      Tyson    Newman  (+353) 8350 2738
# 1  102021803047                       (+353) 8350 2738
# 2  102033748778
# 3  102023206209                       (+353) 8350 2738
#
#                               Email                         original mail  \
# 0  tyson_newman1021718471@yahoo.com  tyson_newman1021718471+103@yahoo.com
# 1  tyson_newman1021718471@yahoo.com  tyson_newman1021718471+101@yahoo.com
# 2  tyson_newman1021718471@yahoo.com      tyson_newman1021718471@yahoo.com
# 3  tyson_newman1021718471@yahoo.com  tyson_newman1021718471+102@yahoo.com
#
#         Create Date Last Activity Date                               Key
# 0  2025-02-25 07:58                     tyson_newman1021718471@yahoo.com
# 1  2025-02-25 07:58                     tyson_newman1021718471@yahoo.com
# 2  2025-02-25 07:58                     tyson_newman1021718471@yahoo.com
# 3  2025-02-25 07:58                     tyson_newman1021718471@yahoo.com

# %% [markdown]
# ## Merge Records

# %%
len('hjgkljyugluygloyug')
# Out:
# 18

# %%
for i in range(49,len(duplicates)):
    
    clear_output(wait=True)#borrar la salida de la celda, para poder imprimir los detalles mas recientes
    
    print('Loop # {} of {}'.format(i, len(duplicates)-1))# aplicar fotmaro en el primer {i} of {duplicates} y el -1 para obtener el ultimo dato 
    
    ## Our key to detect duplicates
    key = duplicates.at[i, 'Key'] #la variable key va almacenar la llave en la fila i, y la columna key 
   
    ## Find Duplicates Frame
    mini = df.loc[(df['Key'] == key)] # guardar en mini  la columna key pero todo lo de la variable key 
    
    ## To select the newest or oldest record as primary_record_id [ascending=True/False]
    #mini = mini.sort_values(by='Create Date', ascending=True) 
    #mini['es_primario'] = ~mini['original mail'].str.contains(r'\+')

    mini['tamEmail']=mini['original mail'].apply(lambda x:len(x))
    
    mini = mini.sort_values(by=['tamEmail'] ,ascending=True)
    mini = mini.reset_index(drop=True)#dejar el index 'predeterminad' o el de defecto
    
    # # # Loop for merging
    primary_record_id = int(mini.at[0, 'Record ID']) # Start record # trae el el record id de mini en entero desde la posicion 0 y dela columna record id 
    
    for j in range(1, len(mini)): #Start in 1 because primary_record_id will be the first [i = 0] in the start
        
        to_merge_record_id = int(mini.at[j, 'Record ID'])# guarda en la variable un entero de cada recorrido en la columna record id 
        
        payload = json.dumps({'primaryObjectId': primary_record_id,
                              'objectIdToMerge': to_merge_record_id})#combierte el las variables a un formato json y toma el record id y lo mergea con el rrecorrido echo
        
        url = 'https://api.hubapi.com/crm/v3/objects/{}/merge'.format(records_object_type)#es un formato para decirle a la url que ahi va lo que el usuario quiera 
        
        api_response = requests.request("POST", url, data=payload, headers=headers) # guardamos lo que responda el llamado 
        
        ## El resultado del merge es un nuevo registro con un nuevo ID, este se convierte en el primary_record_id
        primary_record_id = api_response.json()['id']
        
        print('Merge # {} - Merging {} into {}'.format(j, to_merge_record_id, primary_record_id))
        print(api_response)
        
     ## Puse este break-loop_i para que revise el primer resultado que le dio - recuerde que desmerge no hay
# Out:
# Loop # 49 of 49
# C:\Users\Juan Pablo Pelaez\AppData\Local\Temp\ipykernel_10108\2686015421.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini['tamEmail']=mini['original mail'].apply(lambda x:len(x))
# Merge # 1 - Merging 102021803049 into 102064929568
# <Response [200]>
# Merge # 2 - Merging 102021803051 into 102089672753
# <Response [200]>
# Merge # 3 - Merging 102020822178 into 102055692120
# <Response [200]>
# Merge # 4 - Merging 102033443462 into 102082956606
# <Response [200]>
